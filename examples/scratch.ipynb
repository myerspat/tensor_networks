# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/all_runs.csv', index_col=0)
df.head()
# Out:
#       method policies  trial  comp_ratio      time  count  tree
# 0  partition     UCB1      1   59.325843  0.544731   63.0     1
# 1  partition     UCB1      1  153.043478  0.513183   63.0     2
# 2  partition     UCB1      1  104.900662  0.824935   63.0     3
# 3  partition     UCB1      1   75.071090  0.501962   63.0     4
# 4  partition     UCB1      1  225.480427  0.525694   63.0     5

# %%
ucb1_df = df.loc[df['policies']=='NormalSampling']
ucb1_df.head()
# Out:
#         method        policies  trial  comp_ratio      time  count  tree
# 375  partition  NormalSampling      1  140.800000  0.495823   63.0     1
# 376  partition  NormalSampling      1  104.900662  0.394876   63.0     2
# 377  partition  NormalSampling      1   94.567164  0.445359   63.0     3
# 378  partition  NormalSampling      1   53.423272  0.432028   63.0     4
# 379  partition  NormalSampling      1  169.865952  0.450386   63.0     5

# %%
sns.lineplot(
    data=ucb1_df,
    x='tree',
    y='time',
    hue='method',
    errorbar='sd',
)
# Out:
# <Axes: xlabel='tree', ylabel='time'>
